# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import read_excel

# %%
file_name = 'lyfsense_data.xlsx'
df = read_excel(file_name)

# %%
df
# Out:
#        Unnamed: 0     timestamp      dataId            updatedDT  SystemID  \
# 0               0  1.557362e+09  41611464.0  2019-05-09 00:39:07     103.0
# 1               1  1.557362e+09  41611496.0  2019-05-09 00:39:41     103.0
# 2               2  1.557362e+09  41611523.0  2019-05-09 00:40:17     103.0
# 3               3  1.557362e+09  41611552.0  2019-05-09 00:40:52     103.0
# 4               4  1.557362e+09  41611581.0  2019-05-09 00:41:26     103.0
# 5               5  1.557363e+09  41611613.0  2019-05-09 00:42:01     103.0
# 6               6  1.557363e+09  41611641.0  2019-05-09 00:42:36     103.0
# 7               7  1.557363e+09  41611672.0  2019-05-09 00:43:11     103.0
# 8               8  1.557363e+09  41611702.0  2019-05-09 00:43:46     103.0
# 9               9  1.557363e+09  41611731.0  2019-05-09 00:44:21     103.0
# 10             10  1.557363e+09  41611764.0  2019-05-09 00:44:57     103.0
# ...

# %%
df1 = df.drop(['Unnamed: 0'], axis=1)

# %%
df1.head()
# Out:
#       timestamp      dataId            updatedDT  SystemID             UID  \
# 0  1.557362e+09  41611464.0  2019-05-09 00:39:07     103.0  kripya.d180121
# 1  1.557362e+09  41611496.0  2019-05-09 00:39:41     103.0  kripya.d180121
# 2  1.557362e+09  41611523.0  2019-05-09 00:40:17     103.0  kripya.d180121
# 3  1.557362e+09  41611552.0  2019-05-09 00:40:52     103.0  kripya.d180121
# 4  1.557362e+09  41611581.0  2019-05-09 00:41:26     103.0  kripya.d180121
#
#    DeviceCount  InputPVVoltage  InputPVCurrent  InputPVPower  \
# 0          2.0       35.693696             NaN           0.0
# 1          2.0       35.886784             NaN           0.0
# 2          2.0       35.886784             NaN           0.0
# 3          2.0       36.300544             NaN           0.0
# 4          2.0       36.493632             NaN           0.0
#
#    InputPVEnergyTotal  OutputACVoltage  OutputACCurrent  OutputACPower  \
# 0           93.362885           3.7869              NaN            0.0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63546 entries, 0 to 63545
# Data columns (total 20 columns):
# timestamp                63483 non-null float64
# dataId                   63483 non-null float64
# updatedDT                63483 non-null object
# SystemID                 63483 non-null float64
# UID                      63483 non-null object
# DeviceCount              63483 non-null float64
# InputPVVoltage           63483 non-null float64
# InputPVCurrent           55637 non-null float64
# InputPVPower             63483 non-null float64
# InputPVEnergyTotal       63483 non-null float64
# OutputACVoltage          63483 non-null float64
# OutputACCurrent          55637 non-null float64
# OutputACPower            63483 non-null float64
# OutputACEnergyTotal      63483 non-null float64
# OutputACEnergyOnGrid     63483 non-null float64
# OutputACEnergyOffGrid    63483 non-null float64
# Temperature              63483 non-null float64
# ...

# %%
df1.columns
# Out:
# Index([u'timestamp', u'dataId', u'updatedDT', u'SystemID', u'UID',
#        u'DeviceCount', u'InputPVVoltage', u'InputPVCurrent', u'InputPVPower',
#        u'InputPVEnergyTotal', u'OutputACVoltage', u'OutputACCurrent',
#        u'OutputACPower', u'OutputACEnergyTotal', u'OutputACEnergyOnGrid',
#        u'OutputACEnergyOffGrid', u'Temperature', u'SystemStatus', u'TripError',
#        u'MasterSlave'],
#       dtype='object')

# %%
df1.isnull().sum()
# Out:
# timestamp                  63
# dataId                     63
# updatedDT                  63
# SystemID                   63
# UID                        63
# DeviceCount                63
# InputPVVoltage             63
# InputPVCurrent           7909
# InputPVPower               63
# InputPVEnergyTotal         63
# OutputACVoltage            63
# OutputACCurrent          7909
# OutputACPower              63
# OutputACEnergyTotal        63
# OutputACEnergyOnGrid       63
# OutputACEnergyOffGrid      63
# Temperature                63
# SystemStatus               63
# TripError                  63
# MasterSlave                63
# dtype: int64

# %%
df2=df1[df1['timestamp'].isnull()]

# %%
df7=df4[df4['InputPVCurrent'].isnull()]

# %%
df7.head()
# Out:
#                               timestamp      dataId  SystemID             UID  \
# updatedDT
# 2019-05-09 06:09:07+05:30  1.557362e+09  41611464.0     103.0  kripya.d180121
# 2019-05-09 06:09:41+05:30  1.557362e+09  41611496.0     103.0  kripya.d180121
# 2019-05-09 06:10:17+05:30  1.557362e+09  41611523.0     103.0  kripya.d180121
# 2019-05-09 06:10:52+05:30  1.557362e+09  41611552.0     103.0  kripya.d180121
# 2019-05-09 06:11:26+05:30  1.557362e+09  41611581.0     103.0  kripya.d180121
#
#                            DeviceCount  InputPVVoltage  InputPVCurrent  \
# updatedDT
# 2019-05-09 06:09:07+05:30          2.0       35.693696             NaN
# 2019-05-09 06:09:41+05:30          2.0       35.886784             NaN
# 2019-05-09 06:10:17+05:30          2.0       35.886784             NaN
# 2019-05-09 06:10:52+05:30          2.0       36.300544             NaN
# 2019-05-09 06:11:26+05:30          2.0       36.493632             NaN
#
# ...

# %%
cols = ['InputPVCurrent', 'InputPVVoltage', 'OutputACVoltage', 'OutputACCurrent', 'Temperature', 'OutputACEnergyOnGrid', 'OutputACEnergyOffGrid']
axes = df8[cols].plot(marker='.', alpha=0.5, linestyle='None', figsize=(20, 20), subplots=True)
for ax in axes:
    ax.set_ylabel('Hourly Power Trend')

# %%
df8 = df7.loc['2019-05-09']

# %%
cols = ['InputPVCurrent', 'InputPVVoltage', 'OutputACVoltage', 'OutputACCurrent', 'Temperature', 'OutputACEnergyOnGrid', 'OutputACEnergyOffGrid']
axes = df7[cols].plot(marker='.', alpha=0.5, linestyle='None', figsize=(20, 20), subplots=True)
for ax in axes:
    ax.set_ylabel('Hourly Power Trend')

# %%
df8.shape
# Out:
# (323, 19)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63 entries, 1120 to 63545
# Data columns (total 20 columns):
# timestamp                0 non-null float64
# dataId                   0 non-null float64
# updatedDT                0 non-null object
# SystemID                 0 non-null float64
# UID                      0 non-null object
# DeviceCount              0 non-null float64
# InputPVVoltage           0 non-null float64
# InputPVCurrent           0 non-null float64
# InputPVPower             0 non-null float64
# InputPVEnergyTotal       0 non-null float64
# OutputACVoltage          0 non-null float64
# OutputACCurrent          0 non-null float64
# OutputACPower            0 non-null float64
# OutputACEnergyTotal      0 non-null float64
# OutputACEnergyOnGrid     0 non-null float64
# OutputACEnergyOffGrid    0 non-null float64
# Temperature              0 non-null float64
# SystemStatus             0 non-null object
# TripError                0 non-null object
# ...

# %%
df3=pd.concat([df1, df2]).drop_duplicates(keep=False)
df3.isnull().sum()
# Out:
# timestamp                   0
# dataId                      0
# updatedDT                   0
# SystemID                    0
# UID                         0
# DeviceCount                 0
# InputPVVoltage              0
# InputPVCurrent           7846
# InputPVPower                0
# InputPVEnergyTotal          0
# OutputACVoltage             0
# OutputACCurrent          7846
# OutputACPower               0
# OutputACEnergyTotal         0
# OutputACEnergyOnGrid        0
# OutputACEnergyOffGrid       0
# Temperature                 0
# SystemStatus                0
# TripError                   0
# MasterSlave                 0
# dtype: int64

# %%
df3.dtypes
# Out:
# timestamp                float64
# dataId                   float64
# updatedDT                 object
# SystemID                 float64
# UID                       object
# DeviceCount              float64
# InputPVVoltage           float64
# InputPVCurrent           float64
# InputPVPower             float64
# InputPVEnergyTotal       float64
# OutputACVoltage          float64
# OutputACCurrent          float64
# OutputACPower            float64
# OutputACEnergyTotal      float64
# OutputACEnergyOnGrid     float64
# OutputACEnergyOffGrid    float64
# Temperature              float64
# SystemStatus              object
# TripError                 object
# MasterSlave               object
# dtype: object

# %%
df3['updatedDT'] = pd.to_datetime(df3['updatedDT'])
df3['updatedDT'] = df3['updatedDT'].dt.tz_localize("GMT").dt.tz_convert('Asia/Calcutta')

# %%
df3.dtypes
# Out:
# timestamp                                      float64
# dataId                                         float64
# updatedDT                datetime64[ns, Asia/Calcutta]
# SystemID                                       float64
# UID                                             object
# DeviceCount                                    float64
# InputPVVoltage                                 float64
# InputPVCurrent                                 float64
# InputPVPower                                   float64
# InputPVEnergyTotal                             float64
# OutputACVoltage                                float64
# OutputACCurrent                                float64
# OutputACPower                                  float64
# OutputACEnergyTotal                            float64
# OutputACEnergyOnGrid                           float64
# OutputACEnergyOffGrid                          float64
# Temperature                                    float64
# ...

# %%
df4 = df3.set_index('updatedDT')
df4.head()
# Out:
#                               timestamp      dataId  SystemID             UID  \
# updatedDT
# 2019-05-09 06:09:07+05:30  1.557362e+09  41611464.0     103.0  kripya.d180121
# 2019-05-09 06:09:41+05:30  1.557362e+09  41611496.0     103.0  kripya.d180121
# 2019-05-09 06:10:17+05:30  1.557362e+09  41611523.0     103.0  kripya.d180121
# 2019-05-09 06:10:52+05:30  1.557362e+09  41611552.0     103.0  kripya.d180121
# 2019-05-09 06:11:26+05:30  1.557362e+09  41611581.0     103.0  kripya.d180121
#
#                            DeviceCount  InputPVVoltage  InputPVCurrent  \
# updatedDT
# 2019-05-09 06:09:07+05:30          2.0       35.693696             NaN
# 2019-05-09 06:09:41+05:30          2.0       35.886784             NaN
# 2019-05-09 06:10:17+05:30          2.0       35.886784             NaN
# 2019-05-09 06:10:52+05:30          2.0       36.300544             NaN
# 2019-05-09 06:11:26+05:30          2.0       36.493632             NaN
#
# ...

# %%
df4['Year'] = df4.index.year
df4['Month'] = df4.index.month
df4['Weekday Name'] = df4.index.weekday_name

# %%
df4.tail(15)
# Out:
#                               timestamp      dataId  SystemID             UID  \
# updatedDT
# 2019-05-15 17:38:17+05:30  1.557922e+09  42092345.0     120.0  kripya.d180105
# 2019-05-15 17:38:53+05:30  1.557922e+09  42092375.0     120.0  kripya.d180105
# 2019-05-15 17:39:30+05:30  1.557922e+09  42092410.0     120.0  kripya.d180105
# 2019-05-15 17:40:08+05:30  1.557922e+09  42092450.0     120.0  kripya.d180105
# 2019-05-15 17:40:45+05:30  1.557922e+09  42092483.0     120.0  kripya.d180105
# 2019-05-15 17:41:23+05:30  1.557922e+09  42092519.0     120.0  kripya.d180105
# 2019-05-15 17:42:00+05:30  1.557922e+09  42092552.0     120.0  kripya.d180105
# 2019-05-15 17:42:45+05:30  1.557922e+09  42092594.0     120.0  kripya.d180105
# 2019-05-15 17:43:16+05:30  1.557922e+09  42092623.0     120.0  kripya.d180105
# 2019-05-15 17:44:01+05:30  1.557922e+09  42092664.0     120.0  kripya.d180105
# 2019-05-15 17:44:31+05:30  1.557922e+09  42092696.0     120.0  kripya.d180105
# ...

# %%
df4.sample(5, random_state=0)
# Out:
#                               timestamp      dataId  SystemID             UID  \
# updatedDT
# 2019-05-10 08:06:11+05:30  1.557456e+09  41694993.0     103.0  kripya.d180121
# 2019-05-14 08:27:17+05:30  1.557803e+09  41990270.0     120.0  kripya.d180101
# 2019-05-11 07:00:40+05:30  1.557538e+09  41770076.0     105.0  kripya.d180141
# 2019-05-12 08:59:34+05:30  1.557632e+09  41850174.0     120.0  kripya.d180104
# 2019-05-15 11:07:53+05:30  1.557899e+09  42070861.0     120.0  kripya.d180101
#
#                            DeviceCount  InputPVVoltage  InputPVCurrent  \
# updatedDT
# 2019-05-10 08:06:11+05:30          2.0       35.790240        2.462500
# 2019-05-14 08:27:17+05:30          4.0       32.921504             NaN
# 2019-05-11 07:00:40+05:30          3.0       37.197024        0.973498
# 2019-05-12 08:59:34+05:30          4.0       26.990944        1.544800
# 2019-05-15 11:07:53+05:30          4.0       27.211616        5.385000
#
# ...

# %%
df4['UID'].value_counts()
# Out:
# kripya.d180143    7777
# kripya.d180142    7777
# kripya.d180141    7777
# kripya.d180121    7508
# kripya.d180123    7508
# kripya.d180105    6284
# kripya.d180104    6284
# kripya.d180103    6284
# kripya.d180101    6284
# Name: UID, dtype: int64

# %%
df5 = df4[(df4.UID == 'kripya.d180121')]

# %%
    df5.isnull().sum()
# Out:
# timestamp                  0
# dataId                     0
# SystemID                   0
# UID                        0
# DeviceCount                0
# InputPVVoltage             0
# InputPVCurrent           434
# InputPVPower               0
# InputPVEnergyTotal         0
# OutputACVoltage            0
# OutputACCurrent          434
# OutputACPower              0
# OutputACEnergyTotal        0
# OutputACEnergyOnGrid       0
# OutputACEnergyOffGrid      0
# Temperature                0
# SystemStatus               0
# TripError                  0
# MasterSlave                0
# dtype: int64

# %%
df5.head()
# Out:
#                               timestamp      dataId  SystemID             UID  \
# updatedDT
# 2019-05-09 06:09:07+05:30  1.557362e+09  41611464.0     103.0  kripya.d180121
# 2019-05-09 06:09:41+05:30  1.557362e+09  41611496.0     103.0  kripya.d180121
# 2019-05-09 06:10:17+05:30  1.557362e+09  41611523.0     103.0  kripya.d180121
# 2019-05-09 06:10:52+05:30  1.557362e+09  41611552.0     103.0  kripya.d180121
# 2019-05-09 06:11:26+05:30  1.557362e+09  41611581.0     103.0  kripya.d180121
#
#                            DeviceCount  InputPVVoltage  InputPVCurrent  \
# updatedDT
# 2019-05-09 06:09:07+05:30          2.0       35.693696             NaN
# 2019-05-09 06:09:41+05:30          2.0       35.886784             NaN
# 2019-05-09 06:10:17+05:30          2.0       35.886784             NaN
# 2019-05-09 06:10:52+05:30          2.0       36.300544             NaN
# 2019-05-09 06:11:26+05:30          2.0       36.493632             NaN
#
# ...

# %%
df5['InputPVVoltage'].plot(linewidth=0.5);

# %%
df5['OutputACVoltage'].plot(linewidth=0.5);

# %%
df5['OutputACCurrent'].plot(linewidth=0.5);

# %%
df5['InputPVCurrent'].plot(linewidth=0.5);

# %%
cols = ['InputPVCurrent', 'InputPVVoltage', 'OutputACVoltage', 'OutputACCurrent', 'Temperature', 'OutputACEnergyOnGrid', 'OutputACEnergyOffGrid']
axes = df5[cols].plot(marker='.', alpha=0.5, linestyle='None', figsize=(20, 20), subplots=True)
for ax in axes:
    ax.set_ylabel('Daily Power Trend')

# %%
df6 = df5.loc['2019-05-09']

# %%
cols = ['InputPVCurrent', 'InputPVVoltage', 'OutputACVoltage', 'OutputACCurrent', 'Temperature', 'OutputACEnergyOnGrid', 'OutputACEnergyOffGrid']
axes = df6[cols].plot(marker='.', alpha=0.5, linestyle='None', figsize=(20, 20), subplots=True)
for ax in axes:
    ax.set_ylabel('Hourly Power Trend')

# %%
df9 = df4[(df4.UID == 'kripya.d180123')]

# %%
cols = ['InputPVCurrent', 'InputPVVoltage', 'OutputACVoltage', 'OutputACCurrent', 'Temperature', 'OutputACEnergyOnGrid', 'OutputACEnergyOffGrid']
axes = df9[cols].plot(marker='.', alpha=0.5, linestyle='None', figsize=(20, 20), subplots=True)
for ax in axes:
    ax.set_ylabel('Daily Power Trend')

# %%
df10 = df9.loc['2019-05-09']

# %%
cols = ['InputPVCurrent', 'InputPVVoltage', 'OutputACVoltage', 'OutputACCurrent', 'Temperature', 'OutputACEnergyOnGrid', 'OutputACEnergyOffGrid']
axes = df10[cols].plot(marker='.', alpha=0.5, linestyle='None', figsize=(20, 20), subplots=True)
for ax in axes:
    ax.set_ylabel('Hourly Power Trend')
